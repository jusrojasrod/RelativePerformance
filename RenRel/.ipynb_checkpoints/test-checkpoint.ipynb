# %% [markdown]
# # Rendimiento Relativo
# ---

# %%
# %load_ext autoreload
# %autoreload 2
# import modules

import indicators

import pandas as pd 
import numpy as np
import yfinance as yf

import os
from datetime import date
from datetime import datetime

# %%
folderPath_rsrc = '/Resources/'
folderPath_results = '/Results/'
cwd = os.getcwd()
path_rsrc = cwd + folderPath_rsrc
path_results = cwd + folderPath_results
# read data
ETFs = pd.read_excel(path_rsrc + "ETFs list.xlsx")

# %%
ETFs
# Out:
#     Technology Energy Telecom Consumer Discretionary Real Estate Industrials  \
# 0         AAPB   ACES    FCOM                   AMZD        BBRE        AIRR
# 1         AAPD    AMJ     IXP                   AMZU        BLDG        AQWA
# 2         AAPU   AMLP     IYZ                    BAD        BYRE        ARKX
# 3          AIQ   AMNA     LTL                   BEDZ        CHIR        AWAY
# 4         ARKK   AMND    NXTG                   BETZ        DFGR        BDRY
# ..         ...    ...     ...                    ...         ...         ...
# 163       XPND    NaN     NaN                    NaN         NaN         NaN
# 164        XSD    NaN     NaN                    NaN         NaN         NaN
# 165        XSW    NaN     NaN                    NaN         NaN         NaN
# 166         XT    NaN     NaN                    NaN         NaN         NaN
# 167       XWEB    NaN     NaN                    NaN         NaN         NaN
#
#     Utilities Materials Healthcare Consumer Staples Financials
# 0        BLLD      ALUM       AGNG             CHIS       BDCX
# 1        CHIU      BATT       ARKG             CLIX       BDCZ
# 2        ECLN      CHIM        BBC             EATV       BIZD
# 3        EMIF      CIRC        BBH             EATZ       BNKD
# 4        FUTY      COPX        BBP             ECON       BNKU
# ..        ...       ...        ...              ...        ...
# 163       NaN       NaN        NaN              NaN        NaN
# 164       NaN       NaN        NaN              NaN        NaN
# 165       NaN       NaN        NaN              NaN        NaN
# 166       NaN       NaN        NaN              NaN        NaN
# 167       NaN       NaN        NaN              NaN        NaN
#
# [168 rows x 11 columns]

# %%
sector = "Energy"
energy = ETFs[sector]
energy.dropna(inplace=True)
energy = energy.to_list()

# %% [markdown]
# ## Descargar datos

# %%
energy[:5]
# Out:
# ['ACES', 'AMJ', 'AMLP', 'AMNA', 'AMND']

# %%
# Descargar data diaria
end_ = date.today()  # yyyy-mm-dd
meses_atras = 3  # 3 is fine due we need at least 50 cnadles data.
if end_.day == 31:
    start_ = datetime(end_.year, end_.month - meses_atras, 30)
else:
    start_ = datetime(end_.year, end_.month - meses_atras, end_.day)

data = yf.download(energy, start=start_, end=end_, interval="1d")
# Out:
# [*********************100%%**********************]  86 of 86 completed
# 1 Failed download:
# ['MLPO']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-08-09 00:00:00 -> 2023-11-09)')

# %%
close_df = data.Close

# %%
close_df.head()
# Out:
#                           ACES        AMJ       AMLP       AMNA       AMND  \
# Date
# 2023-08-09 00:00:00  43.720001  23.879999  41.000000  37.842999  38.833000
# 2023-08-10 00:00:00  43.020000  23.879999  40.259998  37.851002  38.785999
# 2023-08-11 00:00:00  42.650002  24.120001  40.770000  38.112999  39.091000
# 2023-08-14 00:00:00  42.700001  23.980000  40.639999  37.791000  38.827999
# 2023-08-15 00:00:00  41.369999  23.770000  40.180000  37.335999  38.358002
#
#                           AMTR    AMUB       AMZA       ATMP        BNE  ...  \
# Date                                                                     ...
# 2023-08-09 00:00:00  50.397999  15.039  33.250000  20.959999  25.458000  ...
# 2023-08-10 00:00:00  50.409000  15.061  33.410000  20.940001  25.219999  ...
# 2023-08-11 00:00:00  50.724998  15.191  33.669998  21.139999  24.898001  ...
# 2023-08-14 00:00:00  50.396000  15.108  33.549999  21.000000  24.681000  ...
# 2023-08-15 00:00:00  49.835999  14.996  33.130001  20.850000  24.165001  ...
#
#                           TPYP        UMI       USAI       VCLN         VDE  \
# Date
# 2023-08-09 00:00:00  25.430000  35.720001  28.040001  19.760000  124.070000
# 2023-08-10 00:00:00  25.389999  35.624001  27.950001  19.511000  123.910004
# 2023-08-11 00:00:00  25.481001  35.888000  28.148001  19.450001  125.680000
# 2023-08-14 00:00:00  25.280001  35.571999  27.886999  19.481001  125.089996
# 2023-08-15 00:00:00  24.997999  35.162998  27.601999  18.865999  122.500000
#
#                           VMAT   WNDY        XES        XLE         XOP
# Date
# 2023-08-09 00:00:00  27.027000  14.96  94.449997  88.550003  148.339996
# 2023-08-10 00:00:00  27.087999  14.85  93.779999  88.540001  147.070007
# 2023-08-11 00:00:00  26.938999  14.52  94.639999  89.900002  148.809998
# 2023-08-14 00:00:00  27.106001  14.55  93.529999  89.519997  147.770004
# 2023-08-15 00:00:00  26.827999  14.18  91.870003  87.660004  145.000000
#
# [5 rows x 86 columns]

# %% [markdown]
# ## 1. Last 50 days mean
# ---

# %% [markdown]
# ### i. Calculate SMA (50 days)

# %%
days = 50
sma = indicators._sma(close_df, period=days)

# %%
sma
# Out:
#                 ACES      AMJ     AMLP      AMNA      AMND      AMTR  \
# Date
# 2023-08-09       NaN      NaN      NaN       NaN       NaN       NaN
# 2023-08-10       NaN      NaN      NaN       NaN       NaN       NaN
# 2023-08-11       NaN      NaN      NaN       NaN       NaN       NaN
# 2023-08-14       NaN      NaN      NaN       NaN       NaN       NaN
# 2023-08-15       NaN      NaN      NaN       NaN       NaN       NaN
# ...              ...      ...      ...       ...       ...       ...
# 2023-11-02  36.22066  24.4506  41.8272  37.53138  38.92608  50.19246
# 2023-11-03  36.07228  24.4854  41.8908  37.55318  38.95616  50.23754
# 2023-11-06  35.89548  24.5228  41.9426  37.56516  38.97664  50.26928
# 2023-11-07  35.71008  24.5528  41.9832  37.56242  38.98384  50.28114
# 2023-11-08  35.47328  24.5746  42.0038  37.54996  38.97984  50.27950
#
#                 AMUB     AMZA     ATMP       BNE  ...      TPYP       UMI  \
# Date                                              ...
# 2023-08-09       NaN      NaN      NaN       NaN  ...       NaN       NaN
# 2023-08-10       NaN      NaN      NaN       NaN  ...       NaN       NaN
# 2023-08-11       NaN      NaN      NaN       NaN  ...       NaN       NaN
# 2023-08-14       NaN      NaN      NaN       NaN  ...       NaN       NaN
# 2023-08-15       NaN      NaN      NaN       NaN  ...       NaN       NaN
# ...              ...      ...      ...       ...  ...       ...       ...
# 2023-11-02  15.39412  34.5825  20.9186  22.17092  ...  24.85998  35.32614
# 2023-11-03  15.41560  34.6311  20.9342  22.12288  ...  24.87158  35.35062
# 2023-11-06  15.43878  34.6737  20.9518  22.06938  ...  24.87438  35.36802
# 2023-11-07  15.45774  34.6995  20.9624  22.00656  ...  24.86978  35.37850
# 2023-11-08  15.47096  34.7117  20.9664  21.92740  ...  24.85718  35.37662
#
#                 USAI      VCLN       VDE      VMAT      WNDY      XES  \
# Date
# 2023-08-09       NaN       NaN       NaN       NaN       NaN      NaN
# 2023-08-10       NaN       NaN       NaN       NaN       NaN      NaN
# 2023-08-11       NaN       NaN       NaN       NaN       NaN      NaN
# 2023-08-14       NaN       NaN       NaN       NaN       NaN      NaN
# 2023-08-15       NaN       NaN       NaN       NaN       NaN      NaN
# ...              ...       ...       ...       ...       ...      ...
# 2023-11-02  27.54348  17.10864  125.2166  26.19180  12.70016  93.6922
# 2023-11-03  27.56026  17.06834  125.2338  26.19364  12.66956  93.6924
# 2023-11-06  27.56936  17.02156  125.1920  26.19234  12.64016  93.6510
# 2023-11-07  27.56784  16.96884  125.0742  26.18814  12.60484  93.4982
# 2023-11-08  27.55940  16.90428  124.9204  26.17648  12.56264  93.3262
#
#                 XLE         XOP
# Date
# 2023-08-09      NaN         NaN
# 2023-08-10      NaN         NaN
# 2023-08-11      NaN         NaN
# 2023-08-14      NaN         NaN
# 2023-08-15      NaN         NaN
# ...             ...         ...
# 2023-11-02  89.2596  147.403199
# 2023-11-03  89.2582  147.473599
# 2023-11-06  89.2204  147.428199
# 2023-11-07  89.1328  147.284399
# 2023-11-08  89.0194  147.065799
#
# [65 rows x 86 columns]

# %% [markdown]
# ### ii. Price porcentual deviation from 50 days mean

# %%
pm = indicators._PM(prices_df=close_df, sma_df=sma)

# %%
pm
# Out:
#                 ACES       AMJ      AMLP      AMNA      AMND      AMTR  \
# Date
# 2023-08-09       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-08-10       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-08-11       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-08-14       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-08-15       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-11-02 -0.135024  0.046600  0.040949  0.018694  0.020293  0.029637
# 2023-11-03 -0.110120  0.049605  0.043666  0.020020  0.024434  0.030683
# 2023-11-06 -0.131646  0.042295  0.033317  0.012135  0.017045  0.022334
# 2023-11-07 -0.131618  0.029211  0.024934  0.000095  0.006879  0.009782
# 2023-11-08 -0.152602  0.016090  0.004671 -0.007429 -0.001407  0.001521
#
#                 AMUB      AMZA      ATMP       BNE  ...      TPYP       UMI  \
# Date                                                ...
# 2023-08-09       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2023-08-10       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2023-08-11       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2023-08-14       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2023-08-15       NaN       NaN       NaN       NaN  ...       NaN       NaN
# ...              ...       ...       ...       ...  ...       ...       ...
# 2023-11-02  0.046763  0.024217  0.037354 -0.076222  ...  0.022446  0.031672
# 2023-11-03  0.050559  0.039817  0.036581 -0.053423  ...  0.024462  0.030477
# 2023-11-06  0.042116  0.033925  0.028551 -0.051854  ...  0.014297  0.023976
# 2023-11-07  0.030422  0.014424  0.017059 -0.060598  ...  0.003226  0.010303
# 2023-11-08  0.015516  0.002832  0.005418 -0.069840  ... -0.004312 -0.001431
#
#                 USAI      VCLN       VDE      VMAT      WNDY       XES  \
# Date
# 2023-08-09       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-08-10       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-08-11       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-08-14       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-08-15       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-11-02  0.021694 -0.061994 -0.015306  0.000962 -0.042925 -0.034285
# 2023-11-03  0.023938 -0.039743 -0.024305  0.015170 -0.014173 -0.038022
# 2023-11-06  0.014242 -0.046386 -0.037638  0.013617 -0.011880 -0.058526
# 2023-11-07  0.001928 -0.053913 -0.060078  0.016109 -0.023788 -0.104368
# 2023-11-08 -0.003643 -0.059291 -0.070288  0.017707 -0.015334 -0.104753
#
#                  XLE       XOP
# Date
# 2023-08-09       NaN       NaN
# 2023-08-10       NaN       NaN
# 2023-08-11       NaN       NaN
# 2023-08-14       NaN       NaN
# 2023-08-15       NaN       NaN
# ...              ...       ...
# 2023-11-02 -0.019041  0.008866
# 2023-11-03 -0.028885  0.000993
# 2023-11-06 -0.039457 -0.025356
# 2023-11-07 -0.059830 -0.052038
# 2023-11-08 -0.070427 -0.071028
#
# [65 rows x 86 columns]

# %% [markdown]
# ## 2. Overbought and Oversold
# ---

# %% [markdown]
# ### i. Relative Strenght Index (RSI)

# %%
days_ = 14
# https://www.macroption.com/rsi-calculation/

# %% [markdown]
# ### ii. Bollinger Bands

# %%
test = indicators._bollinger_bands(close_df['AMJ'])
test
# Out:
#                 close        sma  Upper Band  Lower Band
# Date
# 2023-08-09  23.879999        NaN         NaN         NaN
# 2023-08-10  23.879999        NaN         NaN         NaN
# 2023-08-11  24.120001        NaN         NaN         NaN
# 2023-08-14  23.980000        NaN         NaN         NaN
# 2023-08-15  23.770000        NaN         NaN         NaN
# ...               ...        ...         ...         ...
# 2023-11-02  25.590000  24.956429   25.358689   24.554168
# 2023-11-03  25.700001  25.006429   25.507549   24.505309
# 2023-11-06  25.559999  25.042857   25.591141   24.494573
# 2023-11-07  25.270000  25.045714   25.596590   24.494839
# 2023-11-08  24.969999  25.030714   25.579157   24.482272
#
# [65 rows x 4 columns]

# %%
test[['sma', 'Upper Band', 'Lower Band']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from concurrent.futures import ThreadPoolExecutor

# %%
symbols = close_df.columns[:1].to_list()

# %%
symbols
# Out:
# ['ACES']

# %%
pool = ThreadPoolExecutor(max_workers=5)

# %%
results = pool.map(indicators._bollinger_bands, symbols)

# %%
for res in results:
    print(res.head())
    
pool.shutdown()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 for res in results:
#       2     print(res.head())
#       4 pool.shutdown()
#
# File ~\anaconda3\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~\anaconda3\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~\anaconda3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\anaconda3\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~\Documents\GitHub\Rendimiento-Relativo\RenRel\indicators.py:60, in _bollinger_bands(data, periods, n, column_name)
#      46 def _bollinger_bands(data, periods=14, n=1.5,
#      47                      column_name='close'):
#      48     """
#      49     It uses close prices.
#      50     Parameters
#    (...)
#      58         the std. 1.5 by default.
#      59     """
# ---> 60     sma = _sma(data=data, period=periods)
#      61     std = data.rolling(window=periods).std()
#      62     upBand = sma + n*std
#
# File ~\Documents\GitHub\Rendimiento-Relativo\RenRel\indicators.py:13, in _sma(data, period)
#       4 def _sma(data, period=50):
#       5     """
#       6     Parameters
#       7     ----------
#    (...)
#      11         Lookback period to compute the SMA. 50 by default.
#      12     """
# ---> 13     SMA = data.rolling(window=period).mean()
#      15     return SMA
#
# AttributeError: 'str' object has no attribute 'rolling'

# %%
# https://superfastpython.com/threadpoolexecutor-in-python/
# SuperFastPython.com
# example of executing a target task function in a separate thread
from time import sleep
from threading import Thread
 
# a simple task that blocks for a moment and prints a message
def task():
    # block for a moment
    sleep(1)
    # display a message
    print('This is coming from another thread')
 
# create and configure a new thread to run a function
thread = Thread(target=task)
# start the task in a new thread
thread.start()
# display a message
print('Waiting for the new thread to finish...')
# wait for the task to complete
thread.join()
# Out:
# Waiting for the new thread to finish...
# This is coming from another thread
